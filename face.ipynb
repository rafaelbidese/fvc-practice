# %%
#http://www.scipy-lectures.org/advanced/image_processing/
# imports.
import numpy as np
import imageio
from scipy import misc
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %matplotlib inline

# define variables.
#x = np.linspace(0, 4*np.pi, 100)
#y = np.sin(x)

# plots!
#plt.plot(x,y)
#plt.show()

face = misc.face()

imageio.imwrite('images/face.png', face) # uses the Image module (PIL)

print(type(face))      

print(face.shape, face.dtype)

plt.imshow(face)
plt.show()
#face
# Out:
# <class 'numpy.ndarray'>
# (768, 1024, 3) uint8

# %%
img = mpimg.imread('images/face.png', 'uint8')
print(type(img))
print(img.shape, img.dtype)
# Out:
# <class 'numpy.ndarray'>
# (768, 1024, 3) uint8

# %%
gface = misc.face(gray=True)
plt.imshow(gface)

# %%
plt.imshow(gface, cmap=plt.cm.gray, vmin=30, vmax=200)
